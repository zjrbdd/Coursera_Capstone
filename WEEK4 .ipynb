# %%
import pandas as pd
url='https://raw.githubusercontent.com/zjrbdd/Coursera_Capstone/master/rent%20data.csv'
readfile = pd.read_csv(url)
readfile.head(13)
# Out:
#            NeighborhoodName           City State     CountyName  2018-1  \
# 0          Mission District  San Francisco    CA  San Francisco  3200.0
# 1                  Downtown  San Francisco    CA  San Francisco  2855.0
# 2           Pacific Heights  San Francisco    CA  San Francisco  3500.0
# 3                  Nob Hill  San Francisco    CA  San Francisco  2862.5
# 4           South of Market  San Francisco    CA  San Francisco  3550.0
# 5              Russian Hill  San Francisco    CA  San Francisco  3495.0
# 6              Hayes Valley  San Francisco    CA  San Francisco  3965.0
# 7                    Marina  San Francisco    CA  San Francisco  3300.0
# 8     Lower Pacific Heights  San Francisco    CA  San Francisco  3200.0
# 9               South Beach  San Francisco    CA  San Francisco  3800.0
# 10  Van Ness - Civic Center  San Francisco    CA  San Francisco  3259.0
# 11              Mission Bay  San Francisco    CA  San Francisco  3699.0
# 12      Yerba Buena Gardens  San Francisco    CA  San Francisco  3495.0
#
#     2018-2  2018-3  2018-04  2018-05  2018-06
# 0   3250.0  3195.0   3403.0   3481.0   3350.0
# 1   2950.0  3090.0   3030.0   3095.0   3095.0
# 2   3497.5  3595.0   3695.0   3719.5   3749.0
# 3   2800.0  2795.0   2795.0   2795.0   2700.0
# 4   3709.0  3729.0   3665.0   3667.5   3650.0
# 5   3447.5  3345.0   3474.0   3395.0   3350.0
# 6   4205.0  3985.0   4050.0   4175.0   4130.0
# 7   3286.5  3274.0   3300.0   3400.0   3400.0
# 8   3225.0  3307.0   3358.0   3296.0   3275.0
# 9   3900.0  3897.5   3900.0   3950.0   3925.0
# 10  3253.5  3500.0   3563.0   3500.0   3500.0
# 11  3798.0  3975.5   4013.0   4088.5   4092.5
# 12  3450.0  3620.5   3672.5   3505.0   3625.0

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
address = 'Mission District, San Francisco, CA'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Latitude and longitude of '+address+' are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   from ipykernel import kernelapp as app
# Latitude and longitude of Mission District, San Francisco, CA are 37.75993, -122.4191376.

# %%
CLIENT_ID = 'RKSHTZSMSDFQ1SP1Q5SU1RBYGNTXIHTFUXYQ31ZUPGC13XED' # your Foursquare ID
CLIENT_SECRET = 'DUFPZ2DXGEIFPZCJRMSQTUCA3H0CPDDLLJUD5HSNGUJJV1N4' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RKSHTZSMSDFQ1SP1Q5SU1RBYGNTXIHTFUXYQ31ZUPGC13XED
# CLIENT_SECRET:DUFPZ2DXGEIFPZCJRMSQTUCA3H0CPDDLLJUD5HSNGUJJV1N4

# %%
categoryId= '4bf58dd8d48988d10f941735'   #categoryID for Indian restaurant.
radius=1000                              # radius in meters

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius,
    categoryId)

# %%
import requests 
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eddb61860ba08001b1b0161'},
#  'response': {'venues': [{'id': '5d225f1311549d002302c334',
#     'name': 'Mission Curry House',
#     'location': {'address': '2434 Mission St',
#      'lat': 37.757971000000005,
#      'lng': -122.419302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.757971000000005,
#        'lng': -122.419302}],
#      'distance': 218,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2434 Mission St',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1968388',
#      'url': 'https://www.grubhub.com/restaurant/mission-curry-house-2434-mission-st-san-francisco/1968388?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1968388',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '5b21c973791871002c157bb5',
#     'name': 'Ritu Indian Soul Food',
#     'location': {'address': '3111 24th St',
#      'lat': 37.75237,
#      'lng': -122.414479,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.75237,
#        'lng': -122.414479}],
#      'distance': 936,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3111 24th St',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '5d4cee1e1ffb840008a0085d',
#     'name': 'Aditi Indian Cuisine',
#     'location': {'address': '1101 Valencia St',
#      'crossStreet': 'at 22nd St',
#      'lat': 37.755207,
#      'lng': -122.42085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.755207,
#        'lng': -122.42085}],
#      'distance': 546,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1101 Valencia St (at 22nd St)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1303102',
#      'url': 'https://www.grubhub.com/restaurant/aditi-indian-cuisine-1101-valencia-st-san-francisco/1303102?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1303102',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '57ce0645498e646cd9e9588f',
#     'name': 'Naan N Curry',
#     'location': {'address': '2154 Mission St',
#      'lat': 37.762518,
#      'lng': -122.41971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.762518,
#        'lng': -122.41971}],
#      'distance': 292,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2154 Mission St',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '58ed48c4ce66aa59a771a110',
#     'name': 'Curry Inc. - Indian Palace',
#     'location': {'address': '2154 Mission St',
#      'lat': 37.762521,
#      'lng': -122.419678,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.762521,
#        'lng': -122.419678}],
#      'distance': 292,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2154 Mission St',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '44e799b6f964a52094371fe3',
#     'name': "Aslam's Rasoi",
#     'location': {'address': '1037 Valencia St',
#      'crossStreet': '21st St.',
#      'lat': 37.756324939417965,
#      'lng': -122.42103702638165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.756324939417965,
#        'lng': -122.42103702638165},
#       {'label': 'entrance', 'lat': 37.756304, 'lng': -122.42095}],
#      'distance': 434,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1037 Valencia St (21st St.)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '561524',
#      'url': 'https://www.grubhub.com/restaurant/aslams-rasoi-1037-valencia-st-san-francisco/561524?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=561524',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '66432375'},
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '5092cd73e4b0cb1b305790e2',
#     'name': 'AmberDhara, Valencia',
#     'location': {'address': '680 Valencia St',
#      'crossStreet': '18th street',
#      'lat': 37.761986,
#      'lng': -122.42191499999998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.761986,
#        'lng': -122.42191499999998},
#       {'label': 'entrance', 'lat': 37.762033, 'lng': -122.421762}],
#      'distance': 334,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['680 Valencia St (18th street)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '51243a00e4b06327ea088b09',
#     'name': 'Curry Up Now',
#     'location': {'address': '659 Valencia St',
#      'crossStreet': 'btwn 17th & 18th St',
#      'lat': 37.762319653793774,
#      'lng': -122.42162745926812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.762319653793774,
#        'lng': -122.42162745926812}],
#      'distance': 344,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['659 Valencia St (btwn 17th & 18th St)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '277014',
#      'url': 'https://www.grubhub.com/restaurant/curry-up-now-mission-659-valencia-st-san-francisco/277014?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=277014',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '50b9d389e4b077f48cfff0b5',
#     'name': 'Bhel SF',
#     'location': {'address': '3372 19th St',
#      'crossStreet': 'Mission',
#      'lat': 37.76036743434435,
#      'lng': -122.41883039474487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.76036743434435,
#        'lng': -122.41883039474487}],
#      'distance': 55,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3372 19th St (Mission)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '5775ec91498e65da230f0a57',
#     'name': 'Deccan Spice',
#     'location': {'address': '14513 Lee Jackson Memorial Hwy',
#      'crossStreet': 'btwn 22nd & 23rd St',
#      'lat': 37.754616205482,
#      'lng': -122.42096669378383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.754616205482,
#        'lng': -122.42096669378383}],
#      'distance': 613,
#      'postalCode': '94110',
#      'cc': 'US',
#      'neighborhood': 'Mission District',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['14513 Lee Jackson Memorial Hwy (btwn 22nd & 23rd St)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '332490',
#      'url': 'https://www.grubhub.com/restaurant/deccan-spice-1142-valencia-st-san-francisco/332490?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=332490',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '218618078'},
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '49fd1ce0f964a5200b6f1fe3',
#     'name': 'Pakwan',
#     'location': {'address': '3180-82 16th St',
#      'crossStreet': 'btwn Guerrero & Albion St',
#      'lat': 37.76489902919094,
#      'lng': -122.42368140944069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.76489902919094,
#        'lng': -122.42368140944069}],
#      'distance': 682,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3180-82 16th St (btwn Guerrero & Albion St)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b79f8',
#       'name': 'Pakistani Restaurant',
#       'pluralName': 'Pakistani Restaurants',
#       'shortName': 'Pakistani',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '40870b00f964a52099f21ee3',
#     'name': 'Al Hamra',
#     'location': {'address': '3083 16th St',
#      'crossStreet': 'at Valencia',
#      'lat': 37.7647277,
#      'lng': -122.421325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.7647277,
#        'lng': -122.421325},
#       {'label': 'entrance', 'lat': 37.764846, 'lng': -122.421378}],
#      'distance': 567,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3083 16th St (at Valencia)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '49dad092f964a520b25e1fe3',
#     'name': 'Udupi Palace',
#     'location': {'address': '1007 Valencia St',
#      'crossStreet': 'at 21st St',
#      'lat': 37.75676871020177,
#      'lng': -122.42108520192178,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.75676871020177,
#        'lng': -122.42108520192178},
#       {'label': 'entrance', 'lat': 37.756717, 'lng': -122.420981}],
#      'distance': 391,
#      'postalCode': '94110',
#      'cc': 'US',
#      'neighborhood': 'Mission District',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1007 Valencia St (at 21st St)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1969527',
#      'url': 'https://www.grubhub.com/restaurant/udupi-palace-1007-valencia-st-san-francisco/1969527?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1969527',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '49b22de6f964a520df521fe3',
#     'name': 'Magic Curry Kart',
#     'location': {'address': 'Linda Street',
#      'crossStreet': '19th Street',
#      'lat': 37.7591,
#      'lng': -122.42161993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.7591,
#        'lng': -122.42161993}],
#      'distance': 237,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Linda Street (19th Street)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '575ccdbf498e1d51994fee85',
#     'name': 'DUM Indian Soul Food',
#     'location': {'address': '3111 24th St',
#      'crossStreet': 'at Folsom St',
#      'lat': 37.752394,
#      'lng': -122.414472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.752394,
#        'lng': -122.414472}],
#      'distance': 934,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3111 24th St (at Folsom St)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfde',
#       'name': 'South Indian Restaurant',
#       'pluralName': 'South Indian Restaurants',
#       'shortName': 'South Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '342419',
#      'url': 'https://www.grubhub.com/restaurant/dum-indian-soul-food-3111-24th-st-san-francisco/342419?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=342419',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591588434',
#     'hasPerk': False},
#    {'id': '4f06752f4690081b340b6045',
#     'name': 'Juhu Beach Club @ La Victoria Bakery',
#     'location': {'address': '2937 24th St',
#      'lat': 37.752569,
#      'lng': -122.410715,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.752569,
#        'lng': -122.410715},
#       {'label': 'entrance', 'lat': 37.752618, 'lng': -122.410827}],
#      'distance': 1104,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2937 24th St',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591588434',
#     'hasPerk': False}],
#   'confident': False}}

# %%
Restaurants= len(results['response']['venues'])
print ('There are',  Restaurants , 'restaurants.')
# Out:
# There are 16 restaurants.

# %%
venueid= results['response']['venues'][0]['id']
venueid
# Out:
# '5d225f1311549d002302c334'

# %%
url2 = 'https://api.foursquare.com/v2/venues/5a56d8294b78c509a7e462e7?&client_id={}&client_secret={}&v={}&ll={},{}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude
    )
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5eddb652c546f3001b2002c5'},
#  'response': {'venue': {'id': '5a56d8294b78c509a7e462e7',
#    'name': 'Lotus SF Indian Cuisine',
#    'contact': {'phone': '4158729130',
#     'formattedPhone': '(415) 872-9130',
#     'twitter': 'sflotus',
#     'instagram': 'lotussfcuisineofindia',
#     'facebook': '1874149989490763',
#     'facebookUsername': 'lotussfcuisineofindia',
#     'facebookName': 'Lotus SF'},
#    'location': {'address': '2434 Mission St',
#     'lat': 37.75799598854246,
#     'lng': -122.41903896674205,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.75799598854246,
#       'lng': -122.41903896674205}],
#     'distance': 215,
#     'postalCode': '94110',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['2434 Mission St',
#      'San Francisco, CA 94110',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/lotus-sf-indian-cuisine/5a56d8294b78c509a7e462e7',
#    'categories': [{'id': '4bf58dd8d48988d10f941735',
#      'name': 'Indian Restaurant',
#      'pluralName': 'Indian Restaurants',
#      'shortName': 'Indian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'},
#      'primary': True},
#     {'id': '4bf58dd8d48988d1d3941735',
#      'name': 'Vegetarian / Vegan Restaurant',
#      'pluralName': 'Vegetarian / Vegan Restaurants',
#      'shortName': 'Vegetarian / Vegan',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}},
#     {'id': '4c2cd86ed066bed06c3c5209',
#      'name': 'Gluten-free Restaurant',
#      'pluralName': 'Gluten-free Restaurants',
#      'shortName': 'Gluten-free',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/glutenfree_',
#       'suffix': '.png'}}],
#    'verified': False,
#    'stats': {'tipCount': 5},
#    'closed': True,
#    'url': 'https://lotussanfrancisco.com',
#    'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#    'likes': {'count': 16,
#     'groups': [{'type': 'others', 'count': 16, 'items': []}],
#     'summary': '16 Likes'},
#    'dislike': False,
#    'ok': False,
#    'menu': {'type': 'Menu',
#     'label': 'Menu',
#     'anchor': 'View Menu',
#     'url': 'http://lotussanfrancisco.com/pdf/Lotus%20SF%20Menu.pdf',
#     'mobileUrl': 'http://lotussanfrancisco.com/pdf/Lotus%20SF%20Menu.pdf',
#     'externalUrl': 'http://lotussanfrancisco.com/pdf/Lotus%20SF%20Menu.pdf'},
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 12,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 12,
#       'items': [{'id': '5cad5942178a2a002c3078fc',
#         'createdAt': 1554864450,
#         'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/7227730_FWxYOL-E49NQBapF2LXZ9kFdAhvcgUszxYswLByW61k.jpg',
#         'width': 1079,
#         'height': 1920,
#         'user': {'id': '7227730',
#          'firstName': 'Jaclyn',
#          'lastName': 'H',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/OSOLXNZP30QHKKEJ.jpg'}},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 0, 'items': []},
#    'description': 'This new Indian restaurant in the Mission is on a mission.\nLotus SF serves a modern take on traditional North Indian\ncuisine that is clean, healthy and green. Plenty of vegan, vegetarian\nand gluten-free meals. Everyone says it’s absolutely delicious!',
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1515640873,
#    'tips': {'count': 5,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 5,
#       'items': [{'id': '5b2daef1c53093002cc79d82',
#         'createdAt': 1529720561,
#         'text': 'Everything I had was awesome',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/5b2daef1c53093002cc79d82',
#         'lang': 'en',
#         'likes': {'count': 0, 'groups': []},
#         'logView': True,
#         'agreeCount': 0,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'id': '135686788',
#          'firstName': 'Mark',
#          'lastName': 'C',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/135686788-3N1IYMJJ4Q1N32ET.jpg'}},
#         'authorInteractionType': 'liked'}]}]},
#    'shortUrl': 'http://4sq.com/2Dh2l2K',
#    'timeZone': 'America/Los_Angeles',
#    'listed': {'count': 13,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 13,
#       'items': [{'id': '59aadf3892e7a970f003d61d',
#         'name': 'San Francisco',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '430394794',
#          'firstName': 'Cindy',
#          'lastName': 'R',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/blank_girl.png',
#           'default': True}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/430394794/list/san-francisco',
#         'canonicalUrl': 'https://foursquare.com/user/430394794/list/san-francisco',
#         'createdAt': 1504370488,
#         'updatedAt': 1532792170,
#         'photo': {'id': '4fd25856e4b0d64ed870eaee',
#          'createdAt': 1339185238,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/d-uy6cze-8AIROJToam1DLf0KODB-p9Bc5OVDublldA.jpg',
#          'width': 720,
#          'height': 540,
#          'user': {'id': '196207',
#           'firstName': 'Anubhav',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/KDFIAQQGRVEQOHYX.jpg'}},
#          'visibility': 'public'},
#         'followers': {'count': 0},
#         'listItems': {'count': 8,
#          'items': [{'id': 'v5a56d8294b78c509a7e462e7',
#            'createdAt': 1532550690}]}},
#        {'id': '591294be295513094e59b937',
#         'name': 'San Fran Eats',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '18774533',
#          'firstName': 'Brianna',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/YZBSVZR3F2J2JMRY.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/briannacadalzo/list/san-fran-eats',
#         'canonicalUrl': 'https://foursquare.com/briannacadalzo/list/san-fran-eats',
#         'createdAt': 1494389950,
#         'updatedAt': 1571410654,
#         'followers': {'count': 0},
#         'listItems': {'count': 42, 'items': []}},
#        {'id': '599a3446249623221b797d01',
#         'name': 'Mission',
#         'description': 'Near Capp St. Apt.',
#         'type': 'others',
#         'user': {'id': '135686788',
#          'firstName': 'Mark',
#          'lastName': 'C',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/135686788-3N1IYMJJ4Q1N32ET.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/135686788/list/mission',
#         'canonicalUrl': 'https://foursquare.com/user/135686788/list/mission',
#         'createdAt': 1503278150,
#         'updatedAt': 1548629771,
#         'followers': {'count': 1},
#         'listItems': {'count': 59,
#          'items': [{'id': 'v5a56d8294b78c509a7e462e7',
#            'createdAt': 1516517628}]}},
#        {'id': '57d607bd498e78eea071e739',
#         'name': 'Want To Nom',
#         'description': 'Boba.\nBakeries.\nBars.\nRamen.\n(etc)',
#         'type': 'others',
#         'user': {'id': '149831930',
#          'firstName': 'Nathan',
#          'lastName': 'L',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/149831930-YYLQ34JKHAEFIH42'}},
#         'editable': False,
#         'public': True,
#         'collaborative': True,
#         'url': '/user/149831930/list/want-to-nom',
#         'canonicalUrl': 'https://foursquare.com/user/149831930/list/want-to-nom',
#         'createdAt': 1473644477,
#         'updatedAt': 1573336972,
#         'photo': {'id': '566e53d2498e266e0fc6f1b0',
#          'createdAt': 1450070994,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/86875692_LbaL6esrrZlvVMKE4b4wQhcrPptNkdWiI0dXDsi89gg.jpg',
#          'width': 1440,
#          'height': 1920,
#          'user': {'id': '86875692',
#           'firstName': 'Spencer',
#           'lastName': 'C',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/86875692-152N1D4ZXF4QPBLJ'}},
#          'visibility': 'public'},
#         'followers': {'count': 1},
#         'listItems': {'count': 103,
#          'items': [{'id': 'v5a56d8294b78c509a7e462e7',
#            'createdAt': 1523177097}]}}]}]},
#    'hours': {'status': 'Permanently closed',
#     'richStatus': {'entities': [], 'text': 'Permanently closed'},
#     'isOpen': False,
#     'isLocalHoliday': False,
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Thu, Sun',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–2:30 PM'},
#        {'renderedTime': '5:00 PM–9:30 PM'}],
#       'segments': []},
#      {'days': 'Fri–Sat',
#       'open': [{'renderedTime': '11:30 AM–2:30 PM'},
#        {'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'defaultHours': {'status': 'Permanently closed',
#     'richStatus': {'entities': [], 'text': 'Permanently closed'},
#     'isOpen': False,
#     'isLocalHoliday': False,
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Thu, Sun',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–2:30 PM'},
#        {'renderedTime': '5:00 PM–9:30 PM'}],
#       'segments': []},
#      {'days': 'Fri–Sat',
#       'open': [{'renderedTime': '11:30 AM–2:30 PM'},
#        {'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []}]},
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': [{'type': 'price',
#       'name': 'Price',
#       'summary': '$$',
#       'count': 1,
#       'items': [{'displayName': 'Price',
#         'displayValue': '$$',
#         'priceTier': 2}]},
#      {'type': 'reservations',
#       'name': 'Reservations',
#       'summary': 'Reservations',
#       'count': 3,
#       'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#      {'type': 'payments',
#       'name': 'Credit Cards',
#       'summary': 'Credit Cards',
#       'count': 7,
#       'items': [{'displayName': 'Credit Cards',
#         'displayValue': 'Yes (incl. Discover & Visa)'}]},
#      {'type': 'outdoorSeating',
#       'name': 'Outdoor Seating',
#       'count': 1,
#       'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#      {'type': 'wifi',
#       'name': 'Wi-Fi',
#       'count': 1,
#       'items': [{'displayName': 'Wi-Fi', 'displayValue': 'No'}]},
#      {'type': 'serves',
#       'name': 'Menus',
#       'summary': 'Dessert, Brunch & more',
#       'count': 8,
#       'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#        {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#        {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#        {'displayName': 'Dessert', 'displayValue': 'Dessert'}]},
#      {'type': 'drinks',
#       'name': 'Drinks',
#       'summary': 'Beer & Wine',
#       'count': 5,
#       'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#        {'displayName': 'Wine', 'displayValue': 'Wine'}]},
#      {'type': 'diningOptions',
#       'name': 'Dining Options',
#       'summary': 'Take-out',
#       'count': 5,
#       'items': [{'displayName': 'Take-out', 'displayValue': 'Take-out'}]}]},
#    'bestPhoto': {'id': '5cad5942178a2a002c3078fc',
#     'createdAt': 1554864450,
#     'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/7227730_FWxYOL-E49NQBapF2LXZ9kFdAhvcgUszxYswLByW61k.jpg',
#     'width': 1079,
#     'height': 1920,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '5cad5942178a2a002c3078fc',
#      'value': -14675952},
#     'highlightTextColor': {'photoId': '5cad5942178a2a002c3078fc', 'value': -1},
#     'algoVersion': 3}}}}

# %%
restaurantrating= results2['response']['venue']['rating']
restaurantrating
